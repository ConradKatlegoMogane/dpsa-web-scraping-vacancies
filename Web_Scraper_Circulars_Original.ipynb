# %%
import requests
from bs4 import BeautifulSoup

url = "https://www.dpsa.gov.za/newsroom/psvc/circular-08-of-2026/"
response = requests.get(url)
soup = BeautifulSoup(response.text, "html.parser")

# %% [markdown]
# ## Preview

# %%
print(soup.prettify())
# Out:
# <!DOCTYPE html>
# <html lang="en">
#  <head id="html-head">
#   <title id="html-title">
#    Circular 08 of 2026
#   </title>
#   <meta content="text/html; charset=utf-8" http-equiv="content-type"/>
#   <meta content="width=device-width, initial-scale=1" name="viewport"/>
#   <meta content="" name="description"/>
#   <link href="https://www.dpsa.gov.za/site/templates/styles/uikit.min.css" rel="stylesheet"/>
#   <link href="/site/templates/styles/customuikit.css" rel="stylesheet"/>
#   <link href="/site/templates/styles/timeline.css" rel="stylesheet"/>
#   <link href="favicon.ico" rel="icon" type="image/x-icon"/>
#  </head>
#  <body id="html-body" style="background-color: #fff">
#   <header class="uk-hidden@m uk-margin-top-small uk-margin-left-small uk-width-1-1 uk-child-width-1-1">
#    <a class="uk-padding-small uk-dark" href="#offcanvas-nav" id="offcanvas-toggle" uk-toggle="">
#     <span uk-icon="icon: menu; ratio: 1.3">
#     </span>
#    </a>
#    <div class="">
# ...

# %% [markdown]
# ## View the contents of the webpage

# %% [markdown]
# the pdf links are all contained in the body in table with a td tag

# %%
soup.find_all('h4')
# Out:
# [<h4><a name="082026"></a>Circular 08 of 2026</h4>,
#  <h4>National Departments</h4>,
#  <h4>Provincial Administration</h4>,
#  <h4>This site</h4>,
#  <h4>Newsroom</h4>,
#  <h4>Policy updates</h4>,
#  <h4>Find us on</h4>]

# %%
soup.find_all("td")
# Out:
# [<td>
#  <h4><a name="082026"></a>Circular 08 of 2026</h4>
#  <strong>Posting Date: </strong>6 March 2026<br/>
#  <strong>Full Document: </strong><a href="https://www.dpsa.gov.za/dpsa2g/documents/vacancies/2026/PSV%20CIRCULAR%2008%20of%202026.pdf">Circular 08 (click here to view the full document)</a><br/>
#  <strong>WhatsApp Channel: </strong><a href="https://whatsapp.com/channel/0029Va6W6097DAX6CweOT02m">DPSA Vacancy Circular</a><br/>
#  <strong>Directions: </strong>Click on the name of the department / administration to view vacancies in that particular section
#
#              <table border="0" width="100%">
#  <tbody>
#  <tr align="center" valign="top">
#  <td width="50%">
#  <h4>National Departments</h4>
#  <a href="https://www.dpsa.gov.za/dpsa2g/documents/vacancies/2026/08/a.pdf">Agriculture</a><br/>
#  <a href="https://www.dpsa.gov.za/dpsa2g/documents/vacancies/2026/08/b.pdf">Defence</a><br/>
# ...

# %%
import requests
from bs4 import BeautifulSoup
from urllib.parse import urljoin

links_and_titles = []

# Find all tables within the body
tables = soup.find_all('table')

for table in tables:
    # Find all links within the current table
    anchors = table.find_all('a')
    for anchor in anchors:
        title = anchor.get_text(strip=True)
        href = anchor.get('href')       
        if href:
            # Join relative URLs with the base URL to make them absolute
            absolute_url = urljoin(url, href, h4)
            links_and_titles.append({'title': title, 'url': absolute_url})

# Print the extracted data
for item in links_and_titles:
    print(f"Title: {item['title']}, URL: {item['url']}")

# Optionally, convert to a Pandas DataFrame or save to a CSV file for easier data manipulation.
# Out:
# Title: Circular 08 (click here to view the full document), URL: https://www.dpsa.gov.za/dpsa2g/documents/vacancies/2026/PSV%20CIRCULAR%2008%20of%202026.pdf
# Title: DPSA Vacancy Circular, URL: https://whatsapp.com/channel/0029Va6W6097DAX6CweOT02m
# Title: Agriculture, URL: https://www.dpsa.gov.za/dpsa2g/documents/vacancies/2026/08/a.pdf
# Title: Defence, URL: https://www.dpsa.gov.za/dpsa2g/documents/vacancies/2026/08/b.pdf
# Title: Employment And Labour, URL: https://www.dpsa.gov.za/dpsa2g/documents/vacancies/2026/08/c.pdf
# Title: Forestry, Fisheries And The Environment, URL: https://www.dpsa.gov.za/dpsa2g/documents/vacancies/2026/08/d.pdf
# Title: Government Technical Advisory Centre, URL: https://www.dpsa.gov.za/dpsa2g/documents/vacancies/2026/08/e.pdf
# Title: Home Affairs, URL: https://www.dpsa.gov.za/dpsa2g/documents/vacancies/2026/08/f.pdf
# Title: Justice And Constitutional Development, URL: https://www.dpsa.gov.za/dpsa2g/documents/vacancies/2026/08/g.pdf
# ...
